# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('../data/base.csv')
data.describe()
# Out:
#        numero_solicitacao  maiorAtraso  margemBrutaAcumulada  \
# count         8973.000000  8973.000000           8973.000000
# mean          4550.042015    24.642594              0.362176
# std           2603.485853    66.180793              0.201455
# min              1.000000     0.000000              0.000000
# 25%           2316.000000     3.000000              0.281395
# 50%           4559.000000     6.000000              0.402895
# 75%           6802.000000    22.000000              0.507860
# max           9045.000000  1265.000000              1.000000
#
#        percentualProtestos  prazoMedioRecebimentoVendas  titulosEmAberto  \
# count          7475.000000                  8973.000000     8.973000e+03
# mean              0.019260                    23.083027     6.487101e+04
# std               0.593579                    68.177649     2.482852e+05
# min               0.000000                     0.000000     0.000000e+00
# 25%               0.000000                     0.000000     0.000000e+00
# 50%               0.000000                     0.000000     0.000000e+00
# 75%               0.000000                    30.000000     1.725000e+04
# max              36.983728                  1605.000000     3.938590e+06
#
#        valorSolicitado  diferencaPercentualRisco  percentualRisco  \
# count     8.973000e+03               8973.000000      8973.000000
# mean      7.492436e+05                  0.750321         0.249679
# std       2.261875e+07                  0.146058         0.146058
# min       1.000000e+02                  0.207547         0.000000
# 25%       2.500000e+04                  0.642857         0.142857
# 50%       5.000000e+04                  0.750000         0.250000
# 75%       1.200000e+05                  0.857143         0.357143
# max       1.500000e+09                  1.000000         0.792453
#
#        dashboardCorrelacao  valorAprovado  ativoCirculante  passivoCirculante  \
# count          8973.000000   7.569000e+03     4.733000e+03       4.733000e+03
# mean              0.047236   1.897926e+05     4.451028e+07       3.396815e+07
# std               0.472476   5.435186e+05     4.674534e+08       4.946074e+08
# min              -0.999990   0.000000e+00    -1.700000e+01      -1.134941e+06
# 25%               0.000000   1.510000e+04     8.875850e+05       1.829700e+05
# 50%               0.000000   3.500000e+04     3.996630e+06       1.335189e+06
# 75%               0.000000   1.000000e+05     1.635117e+07       7.449366e+06
# max               0.999990   1.070000e+07     2.903832e+10       2.750382e+10
#
#          totalAtivo  totalPatrimonioLiquido  endividamento  \
# count  4.733000e+03            4.733000e+03   4.733000e+03
# mean   7.073623e+07            2.831172e+07   4.687958e+06
# std    8.878891e+08            2.576755e+08   3.773716e+07
# min   -1.700000e+01           -1.867197e+08   0.000000e+00
# 25%    1.049740e+06            2.328920e+05   0.000000e+00
# 50%    4.637565e+06            1.569857e+06   0.000000e+00
# 75%    1.916744e+07            8.036921e+06   7.416500e+05
# max    5.482350e+10            1.292328e+10   7.406315e+08
#
#        duplicatasAReceber       estoque  faturamentoBruto   margemBruta  \
# count        4.733000e+03  4.733000e+03      8.223000e+03  8.223000e+03
# mean         1.663397e+07  1.523956e+07      5.597420e+07  1.620988e+07
# std          2.979029e+08  8.383792e+07      3.344357e+08  1.163482e+08
# min         -2.278071e+07 -2.632260e+05      0.000000e+00 -6.148721e+08
# 25%          3.920500e+04  1.712860e+05      1.191995e+06  0.000000e+00
# 50%          1.088164e+06  1.063783e+06      3.599483e+06  0.000000e+00
# 75%          6.576243e+06  5.493839e+06      1.584222e+07  3.357474e+06
# max          2.009358e+10  1.293428e+09      6.426115e+09  3.366843e+09
#
#        periodoDemonstrativoEmMeses        custos  anoFundacao  capitalSocial  \
# count                  8223.000000  8.223000e+03  8228.000000   8.228000e+03
# mean                     10.377356  2.839061e+07  2006.027467   1.121453e+07
# std                       3.220965  2.072148e+08    19.424120   9.742853e+07
# min                       1.000000 -3.466338e+08  1000.000000   0.000000e+00
# 25%                      11.000000  0.000000e+00  2000.000000   5.000000e+04
# 50%                      12.000000  0.000000e+00  2009.000000   1.000000e+05
# 75%                      12.000000  4.520907e+06  2015.000000   5.000000e+05
# max                      12.000000  4.393536e+09  2020.000000   4.100000e+09
#
#        scorePontualidade  limiteEmpresaAnaliseCredito
# count        8973.000000                 8.228000e+03
# mean            0.798346                 2.851017e+06
# std             0.379186                 2.672324e+07
# min             0.000000                 0.000000e+00
# 25%             0.887479                 7.360000e+03
# 50%             1.000000                 4.860000e+04
# 75%             1.000000                 3.450000e+05
# max             1.000000                 1.974261e+09

# %%
pd.set_option('display.max_columns', None)
data.head(15)
# Out:
#     numero_solicitacao             razaoSocial           nomeFantasia  \
# 0                    1  James Richardson-Patel     Alexandra Williams
# 1                    2      Dr. Geoffrey Walsh      Mr. Darren Arnold
# 2                    3           Joanna Hudson         Dr. David Rees
# 3                    4    Gordon Jones-Hopkins       Sara Reid-Robson
# 4                    5               Nigel Lee     Dr. Stanley Duncan
# 5                    6            Liam Jackson          Gerard Gordon
# 6                    7   Alexander Baker-Wells       Dr. Caroline Ali
# 7                    8              Jean Berry          Gregory Gould
# 8                    9       Elliot Stephenson          Adrian Graham
# 9                   10         Dr. Dale Dawson          Caroline Hale
# 10                  11            Katie Lawson      Patricia Reynolds
# 11                  12            Ellie Turner          Mohamed Welch
# 12                  13          Kathleen Jones           Toby Coleman
# 13                  14              Nicole Fry           Lewis Harris
# 14                  15     Anthony Moore-Jones  Terence Dean-Thompson
#
#           cnpjSemTraco  maiorAtraso  margemBrutaAcumulada  \
# 0   KEBE17609492220843            0              0.252448
# 1   JRBK88908250677300            0              0.000000
# 2   GCVQ28531614261293            4              0.624777
# 3   KJND32266018316396           20              0.000000
# 4   CGQN15826802440348           20              0.454088
# 5   KAYS53232027306925            0              0.000000
# 6   PYOL43118620147076           16              0.000000
# 7   NLUX93496216176463            4              0.350175
# 8   LOVL82962402474134           43              0.245818
# 9   NXKJ36775578171965           24              0.000012
# 10  SVXA16230297135119            7              0.000000
# 11  ELQK41348591516215           26              0.000000
# 12  TWLY57287382223459            3              0.000000
# 13  PVQV57475295829119           52              0.000000
# 14  XLNC07002754445884            4              0.314575
#
#     percentualProtestos       primeiraCompra  prazoMedioRecebimentoVendas  \
# 0                   0.0  2015-12-10T00:00:00                            0
# 1                   NaN  2019-06-12T17:28:31                            0
# 2                   0.0  2019-11-27T00:00:00                            0
# 3                   NaN  2017-02-13T17:20:27                            0
# 4                   0.0  2010-07-13T00:00:00                           20
# 5                   NaN  2019-06-28T10:25:57                            0
# 6                   NaN  2011-03-02T11:27:13                            0
# 7                   0.0  2007-07-02T00:00:00                          102
# 8                   0.0  2006-07-10T00:00:00                           27
# 9                   0.0  2011-02-24T00:00:00                            0
# 10                  NaN  2012-02-24T16:01:26                            0
# 11                  NaN  2017-12-20T17:03:32                            0
# 12                  NaN  2019-10-10T11:47:29                            0
# 13                  NaN  2006-05-01T13:18:05                            0
# 14                  0.0  2019-03-08T00:00:00                            0
#
#     titulosEmAberto  valorSolicitado                 status  \
# 0              0.00          50000.0       AprovadoAnalista
# 1              0.00          10000.0  DocumentacaoReprovada
# 2              0.00          20000.0       AprovadoAnalista
# 3              0.00          25000.0       AprovadoAnalista
# 4           1486.95          50000.0       AprovadoAnalista
# 5              0.00          25000.0       AprovadoAnalista
# 6              0.00         100000.0       AprovadoAnalista
# 7         208980.00         300000.0       AprovadoAnalista
# 8           6432.00         400000.0       AprovadoAnalista
# 9          22733.33          50000.0  DocumentacaoReprovada
# 10             0.00        1000000.0       AprovadoAnalista
# 11             0.00         200000.0         AprovadoComite
# 12             0.00        1138000.0       AprovadoAnalista
# 13             0.00         350000.0  DocumentacaoReprovada
# 14             0.00         200000.0       AprovadoAnalista
#
#                definicaoRisco  diferencaPercentualRisco  percentualRisco  \
# 0        De 11 a 30 % - Baixo                  0.716981         0.283019
# 1   De 0 a 10 % - Muito Baixo                  1.000000         0.000000
# 2        De 11 a 30 % - Baixo                  0.716981         0.283019
# 3         De 51 a 80 % - Alto                  0.396226         0.603774
# 4        De 11 a 30 % - Baixo                  0.830189         0.169811
# 5        De 31 a 50 % - Médio                  0.622642         0.377358
# 6        De 31 a 50 % - Médio                  0.584906         0.415094
# 7   De 0 a 10 % - Muito Baixo                  0.943396         0.056604
# 8        De 11 a 30 % - Baixo                  0.886792         0.113208
# 9   De 0 a 10 % - Muito Baixo                  1.000000         0.000000
# 10       De 31 a 50 % - Médio                  0.603774         0.396226
# 11       De 31 a 50 % - Médio                  0.584906         0.415094
# 12       De 31 a 50 % - Médio                  0.509434         0.490566
# 13  De 0 a 10 % - Muito Baixo                  1.000000         0.000000
# 14       De 11 a 30 % - Baixo                  0.792453         0.207547
#
#     dashboardCorrelacao  valorAprovado dataAprovadoEmComite  \
# 0          0.000000e+00        50000.0                  NaN
# 1          0.000000e+00            NaN                  NaN
# 2          0.000000e+00        20000.0                  NaN
# 3          4.858111e-01        15000.0                  NaN
# 4          0.000000e+00        50000.0                  NaN
# 5          0.000000e+00        20000.0                  NaN
# 6         -9.975171e-01        80000.0                  NaN
# 7          0.000000e+00       300000.0                  NaN
# 8          0.000000e+00       400000.0                  NaN
# 9          0.000000e+00            NaN                  NaN
# 10        -5.091516e-01       800000.0                  NaN
# 11        -3.000000e-15        50000.0  2020-02-05T19:14:37
# 12         0.000000e+00      1138000.0                  NaN
# 13         0.000000e+00            NaN                  NaN
# 14        -8.660254e-01       200000.0                  NaN
#
#          periodoBalanco  ativoCirculante  passivoCirculante  totalAtivo  \
# 0                   NaN              NaN                NaN         NaN
# 1                   NaN              NaN                NaN         NaN
# 2                   NaN              NaN                NaN         NaN
# 3                   NaN              NaN                NaN         NaN
# 4   2019-09-30T00:00:00       14758917.0         12149031.0  25793410.0
# 5                   NaN              NaN                NaN         NaN
# 6                   NaN              NaN                NaN         NaN
# 7   2019-09-30T03:00:00       17801610.0          2538069.0  19415777.0
# 8   2018-12-31T02:00:00       36827690.0         13843198.0  39455945.0
# 9                   NaN              NaN                NaN         NaN
# 10  2019-06-30T03:00:00        2127907.0           704245.0   3609498.0
# 11  2018-12-31T02:00:00        5369982.0          6118711.0   5595689.0
# 12                  NaN              NaN                NaN         NaN
# 13                  NaN              NaN                NaN         NaN
# 14  2018-12-31T02:00:00       11780048.0         11680162.0  12582116.0
#
#     totalPatrimonioLiquido  endividamento  duplicatasAReceber     estoque  \
# 0                      NaN            NaN                 NaN         NaN
# 1                      NaN            NaN                 NaN         NaN
# 2                      NaN            NaN                 NaN         NaN
# 3                      NaN            NaN                 NaN         NaN
# 4               14544378.0      3039112.0          11797928.0   3047791.0
# 5                      NaN            NaN                 NaN         NaN
# 6                      NaN            NaN                 NaN         NaN
# 7                7519758.0            0.0           3742963.0  11902384.0
# 8               25612746.0            0.0          15980275.0  11420388.0
# 9                      NaN            NaN                 NaN         NaN
# 10               2538787.0       366465.0            973971.0    942096.0
# 11               -720844.0      1715000.0            115000.0   1693990.0
# 12                     NaN            NaN                 NaN         NaN
# 13                     NaN            NaN                 NaN         NaN
# 14                901953.0      1567918.0           6873822.0   2017848.0
#
#     faturamentoBruto  margemBruta  periodoDemonstrativoEmMeses       custos  \
# 0          1766880.0          0.0                         12.0          0.0
# 1                NaN          NaN                          NaN          NaN
# 2          2814940.0          0.0                          7.0          0.0
# 3          1285274.0          0.0                         12.0          0.0
# 4         40779757.0   81459809.0                          9.0   40680051.0
# 5           918476.0          0.0                         12.0          0.0
# 6        239016696.0   -7540544.0                         12.0  156394112.0
# 7         11958227.0    9357949.0                          9.0          0.0
# 8         72479551.0    6233236.0                         12.0  -49267738.0
# 9                NaN          NaN                          NaN          NaN
# 10         4575646.0     296634.0                          6.0   -3299332.0
# 11        13871246.0    -772398.0                         12.0   -9455401.0
# 12               0.0          0.0                          1.0          0.0
# 13               NaN          NaN                          NaN          NaN
# 14        36783195.0    -312950.0                         12.0  -25744597.0
#
#     anoFundacao intervaloFundacao  capitalSocial restricoes empresa_MeEppMei  \
# 0        2003.0  Acima de 17 anos        90000.0      False             True
# 1           NaN               NaN            NaN        NaN              NaN
# 2        2014.0    De 6 a 10 anos        20000.0      False             True
# 3        2013.0    De 6 a 10 anos        30000.0      False             True
# 4        2002.0  Acima de 17 anos        75000.0      False            False
# 5        2011.0    De 6 a 10 anos        15000.0      False             True
# 6        1982.0  Acima de 17 anos     30515674.0       True            False
# 7        2000.0  Acima de 17 anos       120000.0      False            False
# 8        2000.0  Acima de 17 anos      1000000.0      False            False
# 9           NaN               NaN            NaN        NaN              NaN
# 10       2011.0    De 6 a 10 anos        20000.0      False             True
# 11       2009.0   De 11 a 16 anos       600000.0      False            False
# 12       2017.0     De 0 a 5 anos       100000.0      False             True
# 13          NaN               NaN            NaN        NaN              NaN
# 14       1990.0  Acima de 17 anos       530000.0      False            False
#
#     scorePontualidade  limiteEmpresaAnaliseCredito dataAprovadoNivelAnalista
# 0             1.00000                      43200.0       2020-02-03T20:57:33
# 1             0.00000                          NaN                       NaN
# 2             1.00000                       4320.0       2020-02-04T16:40:49
# 3             0.00000                       5920.0       2020-02-04T16:37:52
# 4             1.00000                      89000.0       2020-02-04T15:06:28
# 5             0.00000                      38400.0       2020-02-04T15:10:46
# 6             0.00000                   18132588.0       2020-02-05T14:31:22
# 7             1.00000                     768233.0       2020-02-05T20:05:40
# 8             1.00000                    6910219.0       2020-02-05T20:07:07
# 9             0.83159                          NaN                       NaN
# 10            0.00000                      81000.0       2020-02-05T15:15:10
# 11            0.00000                     183509.0                       NaN
# 12            0.00000                      33000.0       2020-02-04T17:42:58
# 13            0.00000                          NaN                       NaN
# 14            1.00000                    3257020.0       2020-02-05T16:06:44

# %%
data.isnull().sum()
# Out:
# numero_solicitacao                0
# razaoSocial                       0
# nomeFantasia                      0
# cnpjSemTraco                      0
# maiorAtraso                       0
# margemBrutaAcumulada              0
# percentualProtestos            1498
# primeiraCompra                  106
# prazoMedioRecebimentoVendas       0
# titulosEmAberto                   0
# valorSolicitado                   0
# status                            0
# definicaoRisco                    0
# diferencaPercentualRisco          0
# percentualRisco                   0
# dashboardCorrelacao               0
# valorAprovado                  1404
# dataAprovadoEmComite           8415
# periodoBalanco                 4240
# ativoCirculante                4240
# passivoCirculante              4240
# totalAtivo                     4240
# totalPatrimonioLiquido         4240
# endividamento                  4240
# duplicatasAReceber             4240
# estoque                        4240
# faturamentoBruto                750
# margemBruta                     750
# periodoDemonstrativoEmMeses     750
# custos                          750
# anoFundacao                     745
# intervaloFundacao               745
# capitalSocial                   745
# restricoes                      745
# empresa_MeEppMei                745
# scorePontualidade                 0
# limiteEmpresaAnaliseCredito     745
# dataAprovadoNivelAnalista      1962
# dtype: int64

# %%
data.drop([
  'numero_solicitacao',
  'razaoSocial',
  'nomeFantasia',
  'status',
  'restricoes',
  'scorePontualidade',
  'dataAprovadoNivelAnalista',
  'limiteEmpresaAnaliseCredito',
  'valorAprovado',
  'anoFundacao',
  'custos',
  'periodoDemonstrativoEmMeses',
  'dataAprovadoEmComite',
  'dashboardCorrelacao',
  'diferencaPercentualRisco',
  'percentualRisco',
  'periodoBalanco',
  'duplicatasAReceber',
  'primeiraCompra',
  'percentualProtestos',
  'prazoMedioRecebimentoVendas'
], axis=1, inplace=True)

# %%
data.isnull().sum()
# Out:
# cnpjSemTraco                 0
# maiorAtraso                  0
# margemBrutaAcumulada         0
# titulosEmAberto              0
# valorSolicitado              0
# definicaoRisco               0
# ativoCirculante           4240
# passivoCirculante         4240
# totalAtivo                4240
# totalPatrimonioLiquido    4240
# endividamento             4240
# estoque                   4240
# faturamentoBruto           750
# margemBruta                750
# intervaloFundacao          745
# capitalSocial              745
# empresa_MeEppMei           745
# dtype: int64

# %%
num_data = data._get_numeric_data().columns.tolist()
cat_data = set(data.columns) - set(num_data)

print(num_data, cat_data)
# Out:
# ['maiorAtraso', 'margemBrutaAcumulada', 'titulosEmAberto', 'valorSolicitado', 'ativoCirculante', 'passivoCirculante', 'totalAtivo', 'totalPatrimonioLiquido', 'endividamento', 'estoque', 'faturamentoBruto', 'margemBruta', 'capitalSocial'] {'intervaloFundacao', 'cnpjSemTraco', 'empresa_MeEppMei', 'definicaoRisco'}

# %%
for i in cat_data:
    print(data[i].value_counts())
# Out:
# Acima de 17 anos    2681
# De 0 a 5 anos       2199
# De 6 a 10 anos      1785
# De 11 a 16 anos     1563
# Name: intervaloFundacao, dtype: int64
# AVAO63044598911311    25
# GTPO06511661214973    21
# JXCH36268697453955    21
# SPID07567212738639    20
# VVSW90409251685348    20
#                       ..
# FFDA30162346840261     1
# FZAM67912003013290     1
# VKWY52712649875504     1
# QCSZ76425273477324     1
# IPFS70635894073808     1
# Name: cnpjSemTraco, Length: 2829, dtype: int64
# False    5046
# True     3182
# Name: empresa_MeEppMei, dtype: int64
# De 11 a 30 % - Baixo         4486
# De 31 a 50 % - Médio         2509
# De 0 a 10 % - Muito Baixo    1590
# De 51 a 80 % - Alto           388
# Name: definicaoRisco, dtype: int64

# %%
data['definicaoRisco'].value_counts()
# Out:
# De 11 a 30 % - Baixo         4486
# De 31 a 50 % - Médio         2509
# De 0 a 10 % - Muito Baixo    1590
# De 51 a 80 % - Alto           388
# Name: definicaoRisco, dtype: int64

# %%
# transform categorical data to numeric
data['definicaoRisco'] = data['definicaoRisco'].map({'De 11 a 30 % - Baixo': 1, 'De 31 a 50 % - Médio': 2, 'De 0 a 10 % - Muito Baixo': 3, 'De 51 a 80 % - Alto': 4, 'nan': 1})
data['empresa_MeEppMei'] = data['empresa_MeEppMei'].map({True: 1, False: 0, 'nan': 0})
data['intervaloFundacao'] = data['intervaloFundacao'].map({ 'Acima de 17 anos': 4, 'De 11 a 16 anos': 3, 'De 6 a 10 anos': 2, 'De 0 a 5 anos': 1, 'nan': 1 })

# %%
data['definicaoRisco'].fillna(0, inplace=True)
data['empresa_MeEppMei'].fillna(0, inplace=True)
data['intervaloFundacao'].fillna(1, inplace=True)

# %%
# find outliers
features = data.select_dtypes(exclude = ["object"]).columns
features
# Out:
# Index(['maiorAtraso', 'margemBrutaAcumulada', 'titulosEmAberto',
#        'valorSolicitado', 'definicaoRisco', 'ativoCirculante',
#        'passivoCirculante', 'totalAtivo', 'totalPatrimonioLiquido',
#        'endividamento', 'estoque', 'faturamentoBruto', 'margemBruta',
#        'intervaloFundacao', 'capitalSocial', 'empresa_MeEppMei'],
#       dtype='object')

# %%
outliers = data[['maiorAtraso', 'margemBrutaAcumulada', 'titulosEmAberto',
       'valorSolicitado', 'definicaoRisco', 'ativoCirculante',
       'passivoCirculante', 'totalAtivo', 'totalPatrimonioLiquido',
       'endividamento', 'estoque', 'faturamentoBruto', 'margemBruta',
       'intervaloFundacao', 'capitalSocial']]

# %%
for i in outliers:
    sns.boxplot(x=outliers[i])
    plt.show()

# %%
def rm_outliers(data):
    df1 = data.copy()
    data = data[['maiorAtraso', 'margemBrutaAcumulada', 'titulosEmAberto',
       'valorSolicitado', 'definicaoRisco', 'ativoCirculante',
       'passivoCirculante', 'totalAtivo', 'totalPatrimonioLiquido',
       'endividamento', 'estoque', 'faturamentoBruto', 'margemBruta',
       'intervaloFundacao', 'capitalSocial']]
    # q1 = the first quartil | q3 = the third quartil | q2 = interquartile distance
    q1 = data.quantile(0.25)
    q3 = data.quantile(0.75)
    
    q2 = q3 - q1
    # setting the areas = lower and upper bounds equals the median times 1.5
    lower_bound = q1 - (1.5 * q2)
    upper_bound = q3 + (1.5 * q2)
    
    for col in data.columns:
        # if the data in each column that has outliers were below the lower bound then it will set it to the lower bound area. Same with upper bound.
        for i in range(0, len(data[col])):
            if data[col][i] < lower_bound[col]:
                data[col][i] = lower_bound[col]
                
            if data[col][i] > upper_bound[col]:
                data[col][i] = upper_bound[col]
                
    for col in data.columns:
        df1[col] = data[col]
        
    return(df1)

# %%
dt = rm_outliers(data)
dt
# Out:
# /tmp/ipykernel_7943/3744417358.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[col][i] = upper_bound[col]
# /tmp/ipykernel_7943/3744417358.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[col][i] = lower_bound[col]
#             cnpjSemTraco  maiorAtraso  margemBrutaAcumulada  titulosEmAberto  \
# 0     KEBE17609492220843          0.0              0.252448             0.00
# 1     JRBK88908250677300          0.0              0.000000             0.00
# 2     GCVQ28531614261293          4.0              0.624777             0.00
# 3     KJND32266018316396         20.0              0.000000             0.00
# 4     CGQN15826802440348         20.0              0.454088          1486.95
# ...                  ...          ...                   ...              ...
# 8968  YKGZ02907098931653         50.5              0.306580         43125.00
# 8969  UCBM91111020900951         23.0              0.329796             0.00
# 8970  CLDB61185288622179          3.0              0.383919          2933.38
# 8971  BRJP37453437154592         11.0              0.424099         43125.00
# 8972  COZD54939108010752          4.0              0.365041         13640.01
#
#       valorSolicitado  definicaoRisco  ativoCirculante  passivoCirculante  \
# 0             50000.0             1.0              NaN                NaN
# 1             10000.0             3.0              NaN                NaN
# 2             20000.0             1.0              NaN                NaN
# 3             25000.0             3.5              NaN                NaN
# 4             50000.0             1.0       14758917.0         12149031.0
# ...               ...             ...              ...                ...
# 8968         262500.0             3.0              NaN                NaN
# 8969         150000.0             3.0              NaN                NaN
# 8970         150000.0             3.0              NaN                NaN
# 8971         262500.0             3.0              NaN                NaN
# 8972          50000.0             3.0              NaN                NaN
#
#       totalAtivo  totalPatrimonioLiquido  endividamento    estoque  \
# 0            NaN                     NaN            NaN        NaN
# 1            NaN                     NaN            NaN        NaN
# 2            NaN                     NaN            NaN        NaN
# 3            NaN                     NaN            NaN        NaN
# 4     25793410.0              14544378.0      1854125.0  3047791.0
# ...          ...                     ...            ...        ...
# 8968         NaN                     NaN            NaN        NaN
# 8969         NaN                     NaN            NaN        NaN
# 8970         NaN                     NaN            NaN        NaN
# 8971         NaN                     NaN            NaN        NaN
# 8972         NaN                     NaN            NaN        NaN
#
#       faturamentoBruto  margemBruta  intervaloFundacao  capitalSocial  \
# 0            1766880.0         0.00                4.0        90000.0
# 1                  NaN          NaN                1.0            NaN
# 2            2814940.0         0.00                2.0        20000.0
# 3            1285274.0         0.00                2.0        30000.0
# 4           37817552.5   8393686.25                4.0        75000.0
# ...                ...          ...                ...            ...
# 8968               NaN          NaN                1.0            NaN
# 8969               NaN          NaN                1.0            NaN
# 8970               NaN          NaN                1.0            NaN
# 8971               NaN          NaN                1.0            NaN
# 8972               NaN          NaN                1.0            NaN
#
#       empresa_MeEppMei
# 0                  1.0
# 1                  0.0
# 2                  1.0
# 3                  1.0
# 4                  0.0
# ...                ...
# 8968               0.0
# 8969               0.0
# 8970               0.0
# 8971               0.0
# 8972               0.0
#
# [8973 rows x 17 columns]

# %%
dt_outliers = dt[['maiorAtraso', 'margemBrutaAcumulada', 'titulosEmAberto',
       'valorSolicitado', 'definicaoRisco', 'ativoCirculante',
       'passivoCirculante', 'totalAtivo', 'totalPatrimonioLiquido',
       'endividamento', 'estoque', 'faturamentoBruto', 'margemBruta',
       'intervaloFundacao', 'capitalSocial']]

# %%
for i in outliers:
    sns.boxplot(x=dt_outliers[i])
    plt.show()

# %%
def fill_median(d, col):
  d.loc[d[col].isnull(), col] = d[col].median()

for col in dt.columns:
  if dt[col].isnull().sum() > 0:
    fill_median(dt, col)

# %%
dt.dtypes.value_counts()
# Out:
# float64    16
# object      1
# dtype: int64

# %%
dt.isnull().sum()
# Out:
# cnpjSemTraco              0
# maiorAtraso               0
# margemBrutaAcumulada      0
# titulosEmAberto           0
# valorSolicitado           0
# definicaoRisco            0
# ativoCirculante           0
# passivoCirculante         0
# totalAtivo                0
# totalPatrimonioLiquido    0
# endividamento             0
# estoque                   0
# faturamentoBruto          0
# margemBruta               0
# intervaloFundacao         0
# capitalSocial             0
# empresa_MeEppMei          0
# dtype: int64

# %%
# string categoricals features
# one_hot_encode_cols = data.dtypes[data.dtypes == object]  # filtering by string categoricals
# one_hot_encode_cols = one_hot_encode_cols.index.tolist()  # list of categorical fields
# one_hot_encode_cols

# %%
# Encode these columns as categoricals so one hot encoding works on split data (if desired)
# for col in one_hot_encode_cols:
#     if col != 'cnpjSemTraco':
#         data[col] = pd.Categorical(data[col])

# # Do the one hot encoding
# data = pd.get_dummies(data, columns=one_hot_encode_cols, drop_first=True)

# %%
# corr heatmap
corr = dt.corr(numeric_only=True)
plt.figure(figsize=(10,10))
plt.matshow(corr, fignum=1)
plt.xticks(range(len(corr.columns)), corr.columns, rotation=90)
plt.yticks(range(len(corr.columns)), corr.columns)
plt.colorbar()
plt.show()

# %%
from sklearn.cluster import KMeans

# %%
# Executar K-means com diferentes números de clusters
to_cluster = dt.drop(['cnpjSemTraco'], axis=1)
distortions = []
for i in range(1, 11):
    km = KMeans(n_clusters=i, init='k-means++', n_init=10, max_iter=300, random_state=42)
    km.fit(to_cluster)
    distortions.append(km.inertia_)

# Plotar o gráfico de cotovelo
plt.plot(range(1, 11), distortions, marker='o')
plt.xlabel('Número de clusters')
plt.ylabel('Distortion')
plt.show()

# %%
from math import sqrt

# %%
def calculate_wcss(data):
    wcss = []
    for n in range(2, 21):
        kmeans = KMeans(n_clusters=n, n_init=10, random_state=42)
        kmeans.fit(X=data)
        wcss.append(kmeans.inertia_)

    return wcss

def optimal_number_of_clusters(wcss):
    x1, y1 = 2, wcss[0]
    x2, y2 = 20, wcss[len(wcss)-1]

    distances = []
    for i in range(len(wcss)):
        x0 = i+2
        y0 = wcss[i]
        numerator = abs((y2-y1)*x0 - (x2-x1)*y0 + x2*y1 - y2*x1)
        denominator = sqrt((y2 - y1)**2 + (x2 - x1)**2)
        distances.append(numerator/denominator)
    
    return distances.index(max(distances)) + 2

sum_of_squares = calculate_wcss(to_cluster)
n = optimal_number_of_clusters(sum_of_squares)
n
# Out:
# 5

# %%
kmeans = KMeans(n_clusters=4, n_init=10, random_state=42)
kmeans.fit(X=to_cluster)
clusters = kmeans.fit_predict(to_cluster)
data['cluster'] = clusters

# %%
data['cluster'].value_counts()
# Out:
# 0    6754
# 3     825
# 2     771
# 1     623
# Name: cluster, dtype: int64

# %%
# plot clusters
from sklearn.decomposition import PCA

pca = PCA(n_components=n)
pca.fit(to_cluster)
pca_data = pca.transform(to_cluster)

plt.figure(figsize=(10,10))
plt.scatter(pca_data[:,0], pca_data[:,1], c=clusters, cmap='rainbow')
plt.show()
